# %% [markdown]
# # Install enviroment

# %%
# !pip install -q -U openmim
# !mim install mmcv-full

# %%
# install dependencies: (use cu111 because colab has CUDA 11.1)
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html

# install mmcv-full thus we could use CUDA operators
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu111/torch1.9.0/index.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.9.0+cu111 (from versions: 1.11.0, 1.11.0+cpu, 1.11.0+cu102, 1.11.0+cu113, 1.11.0+cu115, 1.11.0+rocm4.3.1, 1.11.0+rocm4.5.2, 1.12.0, 1.12.0+cpu, 1.12.0+cu102, 1.12.0+cu113, 1.12.0+cu116, 1.12.0+rocm5.0, 1.12.0+rocm5.1.1, 1.12.1, 1.12.1+cpu, 1.12.1+cu102, 1.12.1+cu113, 1.12.1+cu116, 1.12.1+rocm5.0, 1.12.1+rocm5.1.1, 1.13.0, 1.13.0+cpu, 1.13.0+cu116, 1.13.0+cu117, 1.13.0+cu117.with.pypi.cudnn, 1.13.0+rocm5.1.1, 1.13.0+rocm5.2, 1.13.1, 1.13.1+cpu, 1.13.1+cu116, 1.13.1+cu117, 1.13.1+cu117.with.pypi.cudnn, 1.13.1+rocm5.1.1, 1.13.1+rocm5.2, 2.0.0, 2.0.0+cpu, 2.0.0+cpu.cxx11.abi, 2.0.0+cu117, 2.0.0+cu117.with.pypi.cudnn, 2.0.0+cu118, 2.0.0+rocm5.3, 2.0.0+rocm5.4.2)
# ERROR: No matching distribution found for torch==1.9.0+cu111
# ...

# %%
# Install mmdetection
# %cd drive/MyDrive/mmdetection

# !pip install -q -v -e .
# Out:
# /content/drive/MyDrive/mmdetection
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/mmdetection
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for mmdet
# ...

# %%
import mmcv

print(mmcv.__version__)
# Out:
# 1.7.1
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %%
# Check Pytorch installation
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

# Check MMDetection installation
import mmdet
print(mmdet.__version__)

# Check mmcv installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())
# Out:
# 2.0.0+cu118 True
# 2.28.1
# 11.8
# GCC 9.4

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Side view

# %%
# !python tools/test.py \
    configs/yolo/yolov3_sideview.py \
    checkpoints/sideview_yolov3_epoch_132.pth \
    --out result_yolov3_side.pkl \
    --eval bbox \
    --cfg-options {model.test_cfg.score_thr=0.1,model.test_cfg.nms.iou_threshold=0.7}
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /content/drive/MyDrive/mmdetection/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %%
# !python tools/test.py \
    configs/yolox/yolox_s_sideview_testOnly.py \
    train_yolox_s_on_Sideview-traffic-video-3/best_bbox_mAP_epoch_108.pth \
    --out result_yolox_s_side.pkl \
    --eval bbox \
    --cfg-options {model.test_cfg.score_thr=0.1,model.test_cfg.nms.iou_threshold=0.7}
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /content/drive/MyDrive/mmdetection/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %%
# !python tools/analysis_tools/confusion_matrix.py \
        configs/yolox/yolox_s_sideview_testOnly.py \
        result_yolox_s_side.pkl \
        results/yolox_s \
        --show \
        --score-thr 0.1 \
        --nms-iou-thr 0.7 \
        --tp-iou-thr 0.5 \
        --color-theme seismic
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>] 205/205, 478.1 task/s, elapsed: 0s, ETA:     0sFigure(630x504)

# %%
# !python tools/test.py \
#     configs/yolox/yolox_l_sideview_testOnly.py \
#     checkpoints/sideview_yolox_l_epoch_120.pth \
#     --out result_yolox_l_side.pkl \
#     --eval bbox \
#     --cfg-options {model.test_cfg.score_thr=0.8,model.test_cfg.nms.iou_threshold=0.65}

# %%
# !python tools/test.py \
    configs/yolox/yolox_x_sideview_testOnly.py \
    train_yolox_x_on_Sideview-traffic-video-3/epoch_84.pth \
    --out result_yolox_x_side.pkl \
    --eval bbox \
    --cfg-options {model.test_cfg.score_thr=0.1,model.test_cfg.nms.iou_threshold=0.7}
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /content/drive/MyDrive/mmdetection/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %%
# !python tools/analysis_tools/analyze_results.py \
       configs/yolox/yolox_x_sideview_testOnly.py \
       result_yolox_x_side.pkl \
       results/yolox_x/side/ \
       --topk 100
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>] 205/205, 9.8 task/s, elapsed: 21s, ETA:     0s

# %%
# !python tools/analysis_tools/confusion_matrix.py \
        configs/yolox/yolox_x_sideview_testOnly.py \
        result_yolox_x_side.pkl \
        results/yolox_x \
        --show \
        --score-thr 0.1 \
        --nms-iou-thr 0.7 \
        --tp-iou-thr 0.95 \
        --color-theme seismic
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>] 205/205, 336.1 task/s, elapsed: 1s, ETA:     0sFigure(630x504)

# %% [markdown]
# ## Top view

# %%
# !python tools/test.py \
    configs/yolo/yolov3_topview.py \
    checkpoints/topview_yolov3_epoch_108.pth \
    --out result_yolov3_top.pkl \
    --eval bbox \
    --cfg-options {model.test_cfg.score_thr=0.1,model.test_cfg.nms.iou_threshold=0.7}
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /content/drive/MyDrive/mmdetection/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %%
# !python tools/test.py \
    configs/yolox/yolox_s_topview_testOnly.py \
    train_yolox_s_on_front-top-traffic-video-3/epoch_300.pth \
    --out result_yolox_s_top.pkl \
    --eval bbox \
    --cfg-options {model.test_cfg.score_thr=0.1,model.test_cfg.nms.iou_threshold=0.7}
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /content/drive/MyDrive/mmdetection/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %%
# !python tools/analysis_tools/confusion_matrix.py \
        configs/yolox/yolox_s_topview_testOnly.py \
        result_yolox_s_top.pkl \
        results/yolox_s \
        --show \
        --score-thr 0.1 \
        --nms-iou-thr 0.7 \
        --tp-iou-thr 0.5 \
        --color-theme seismic
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [>>] 485/485, 370.7 task/s, elapsed: 1s, ETA:     0sFigure(630x504)

# %%
# !python tools/test.py \
#     configs/yolox/yolox_l_topview_testOnly.py \
#     checkpoints/topview_yolox_l_epoch_96.pth \
#     --out result_yolox_l_top.pkl \
#     --eval bbox \
#     --cfg-options {model.test_cfg.score_thr=0.8,model.test_cfg.nms.iou_threshold=0.65}

# %%
# !python tools/test.py \
    configs/yolox/yolox_x_topview_testOnly.py \
    train_yolox_x_on_front-top-traffic-video-3/best_bbox_mAP_epoch_108.pth \
    --out result_yolox_x_top.pkl \
    --eval bbox \
    --cfg-options {model.test_cfg.score_thr=0.1,model.test_cfg.nms.iou_threshold=0.7}
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /content/drive/MyDrive/mmdetection/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %%
# !python tools/analysis_tools/confusion_matrix.py \
        configs/yolox/yolox_x_topview_testOnly.py \
        result_yolox_x_top.pkl \
        results/yolox_x \
        --show \
        --score-thr 0.1 \
        --nms-iou-thr 0.7 \
        --tp-iou-thr 0.5 \
        --color-theme seismic
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [>>] 485/485, 406.3 task/s, elapsed: 1s, ETA:     0sFigure(630x504)

# %% [markdown]
# ## Plot confusion matrix

# %% [markdown]
# ### Side view

# %%
# !python tools/analysis_tools/confusion_matrix.py \
        configs/yolo/yolov3_sideview.py \
        result_yolov3_side.pkl \
        confusion_matrix \
        --show
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>] 127/127, 2027.5 task/s, elapsed: 0s, ETA:     0sFigure(630x504)

# %%
# !python tools/analysis_tools/confusion_matrix.py configs/yolo/yolov3_topview.py  result_yolov3_top.pkl  confusion_matrix
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>] 98/98, 1475.8 task/s, elapsed: 0s, ETA:     0s

# %%
# !python tools/analysis_tools/confusion_matrix.py \
        configs/yolox/yolox_s_sideview_testOnly.py \
        result_yolox_s_side.pkl \
        confusion_matrix/sideview/
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>] 127/127, 2176.1 task/s, elapsed: 0s, ETA:     0s

# %%
# !python tools/analysis_tools/confusion_matrix.py \
        configs/yolox/yolox_l_sideview_testOnly.py \
        result_yolox_l_side.pkl \
        confusion_matrix/sideview/
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>] 127/127, 2642.2 task/s, elapsed: 0s, ETA:     0s

# %% [markdown]
# ### Top view
